# %%
pip install sysidentpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-62a59b38-7a8f-4fc1-b719-a4637964154f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62a59b38-7a8f-4fc1-b719-a4637964154f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install numpy pandas matplotlib statsmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from sysidentpy.model_structure_selection import FROLS
from sysidentpy.basis_function._basis_function import Polynomial
from sysidentpy.metrics import root_relative_squared_error
from sysidentpy.utils.display_results import results
from sysidentpy.utils.plotting import plot_residues_correlation, plot_results
from sysidentpy.residues.residues_correlation import compute_residues_autocorrelation, compute_cross_correlation
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
# %matplotlib inline
var=pd.read_excel('Final Dataset.xlsx', sheet_name='Model_Dataset', skiprows=[0, 2]) 
# var.dropna(inplace=True)
var.head()
# Out:
#         Date   BNB-USD   BTC-USD   ETH-USD  USDT-USD   XRP-USD   ADA-USD  \
# 0 2019-01-03 -0.283723 -0.146478 -0.218059 -0.242175 -0.213296 -0.133797
# 1 2019-01-04  0.250258  0.067790  0.155431  0.110796  0.026443 -0.276461
# 2 2019-01-05  0.034520  0.058029  0.065619  0.024849  0.003227  0.448817
# 3 2019-01-06  0.314991  0.085648 -0.032553  0.056192  0.085732  0.716078
# 4 2019-01-07 -0.092145 -0.068087 -0.175156 -0.115993  0.013049 -0.117139
#
#    BITG-USD  MIOTA-USD   XNO-USD  POWR-USD     Power  Ground Transport  \
# 0  0.272976  -0.350994 -0.212519 -0.541858  0.017161          0.100704
# 1 -0.199125   0.001564  0.155184 -0.798119  0.015954          0.002050
# 2 -1.063302  -0.364719  0.394051  0.533827 -0.031367         -0.072048
# 3 -0.655398   0.427898  0.268170  1.404755 -0.020110         -0.145075
# 4  0.675955  -0.436056 -0.465483 -1.400369  0.045889          0.199612
#
#    Residential  Domestic Aviation  International Aviation
# ...

# %%
XNOUSD_var=var.iloc[:, 9]

# %%
output_var=var.iloc[:, 11]

# %%
var.isna()
# Out:
#        Date  BNB-USD  BTC-USD  ETH-USD  USDT-USD  XRP-USD  ADA-USD  BITG-USD  \
# 0     False    False    False    False     False    False    False     False
# 1     False    False    False    False     False    False    False     False
# 2     False    False    False    False     False    False    False     False
# 3     False    False    False    False     False    False    False     False
# 4     False    False    False    False     False    False    False     False
# ...     ...      ...      ...      ...       ...      ...      ...       ...
# 1544  False    False    False    False     False    False    False     False
# 1545  False    False    False    False     False    False    False     False
# 1546  False    False    False    False     False    False    False     False
# 1547  False    False    False    False     False    False    False     False
# 1548  False    False    False    False     False    False    False     False
#
# ...

# %%
var=var.drop(columns=["BTC-USD", "ETH-USD",	"USDT-USD",	"XRP-USD", "BNB-USD",	"BITG-USD",	"MIOTA-USD",	"ADA-USD",	"POWR-USD", "Ground Transport", "Residential", "Domestic Aviation", "International Aviation"])

# %%
var.isnull().sum()
# Out:
# Date       0
# XNO-USD    5
# Power      0
# dtype: int64

# %%
var.dropna(inplace=True)

# %%
var.isnull().sum()
# Out:
# Date       0
# XNO-USD    0
# Power      0
# dtype: int64

# %%
len(var)
# Out:
# 1544

# %%
var.tail()
# Out:
#            Date   XNO-USD     Power
# 1544 2023-03-27  0.560871  0.037557
# 1545 2023-03-28 -0.269928  0.031142
# 1546 2023-03-29 -0.389168 -0.016223
# 1547 2023-03-30 -0.139464 -0.022966
# 1548 2023-03-31 -0.113315 -0.020821

# %%
var['XNO-USD'][0:1550].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
var['Power'][0:1550].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
var[['XNO-USD', 'Power']][0:1550].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
df=pd.DataFrame(var['XNO-USD'])
x = df.to_numpy()
df1=pd.DataFrame(var['Power'])
S= df1.to_numpy()

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x,S,train_size=0.85,shuffle= False)

# %%
df
# Out:
#        XNO-USD
# 0    -0.212519
# 1     0.155184
# 2     0.394051
# 3     0.268170
# 4    -0.465483
# ...        ...
# 1544  0.560871
# 1545 -0.269928
# 1546 -0.389168
# 1547 -0.139464
# 1548 -0.113315
#
# [1544 rows x 1 columns]

# %%
df1
# Out:
#          Power
# 0     0.017161
# 1     0.015954
# 2    -0.031367
# 3    -0.020110
# 4     0.045889
# ...        ...
# 1544  0.037557
# 1545  0.031142
# 1546 -0.016223
# 1547 -0.022966
# 1548 -0.020821
#
# [1544 rows x 1 columns]

# %%
len(x_valid)
# Out:
# 232

# %%
len(y_valid)
# len(y_train)
# Out:
# 232

# %%
len(x_train)
# Out:
# 1312

# %%
# # Concatenate input features and target variable for the validation set
# valid_data = np.column_stack((x_valid, y_valid))

# %%
basis_function = Polynomial(degree=3)

model = FROLS(
    order_selection=True,
    n_terms=50,
    extended_least_squares=False,
    ylag=15,
    xlag=15,   
    info_criteria='bic',
    estimator='least_squares',
    basis_function=basis_function
)
# Out:
# /usr/local/lib/python3.10/dist-packages/sysidentpy/utils/deprecation.py:37: FutureWarning: Passing a string to define the estimator will rise an error in v0.4.0.
#  You'll have to use FROLS(estimator=LeastSquares()) instead.
#  The only change is that you'll have to define the estimator first instead of passing a string like 'least_squares'.
#  This change will make easier to implement new estimators and it'll improve code readability.
#   warnings.warn(message, FutureWarning)

# %%
model.fit(X=x_train, y=y_train)

# %%
yhat = model.predict(X=x_valid, y=y_valid, steps_ahead=None)
rrse = root_relative_squared_error(y_valid, yhat)
print(rrse)

r = pd.DataFrame(
    results(
        model.final_model, model.theta, model.err,
        model.n_terms, err_precision=8, dtype='sci'
        ),
    columns=['Regressors', 'Parameters', 'ERR'])
print(r)
# Out:
# 1.3460195426759427
#                 Regressors   Parameters             ERR
# 0                   y(k-7)   5.0943E-01  6.82838159E-01
# 1                  y(k-14)   3.1097E-01  5.08448018E-02
# 2      y(k-11)y(k-7)y(k-4)  -1.3785E+02  8.48121862E-03
# 3          y(k-10)^2y(k-7)  -4.0856E+01  5.46836584E-03
# 4        x1(k-14)^2y(k-12)  -8.3877E-02  4.33577575E-03
# 5                   y(k-3)  -1.1969E-01  4.44474434E-03
# 6           y(k-5)^2y(k-4)  -2.5802E+01  4.52046095E-03
# 7             y(k-7)y(k-1)  -4.2192E+00  4.67151216E-03
# 8         y(k-14)y(k-11)^2  -5.4892E+01  4.05270921E-03
# 9                   y(k-2)  -1.7867E-01  3.04481230E-03
# 10     y(k-11)y(k-4)y(k-1)   9.6820E+01  4.26553358E-03
# 11         y(k-14)y(k-7)^2  -7.5196E+01  3.94067097E-03
# 12            y(k-9)y(k-2)   1.8458E+00  4.47319618E-03
# 13               y(k-12)^2  -1.0807E+00  4.35023296E-03
# 14    x1(k-8)x1(k-5)y(k-1)   2.1588E-01  2.21999908E-03
# ...

# %%
r["ERR"] = pd.to_numeric(r["ERR"], downcast="float") 
    
print('Sum of ERR=  ',r['ERR'].sum())
# Out:
# Sum of ERR=   0.84035444

# %%
plot_results(y=y_valid, yhat = yhat, n=250)
ee = compute_residues_autocorrelation(y_valid, yhat)
plot_residues_correlation(data=ee, title="Residues", ylabel="$e^2$")
x1e = compute_cross_correlation(y_valid, yhat, x_valid)
plot_residues_correlation(data=x1e, title="Residues", ylabel="$x_1e$")

# %%
yhat = model.predict(X=x_valid, y=y_valid, steps_ahead=1)
rrse = root_relative_squared_error(y_valid, yhat)
print(rrse)
plot_results(y=y_valid, yhat = yhat, n=250)
# Out:
# 0.8027933651716046

# %%
yhat = model.predict(X=x_valid, y=y_valid, steps_ahead=20)
rrse = root_relative_squared_error(y_valid, yhat)
print(rrse)
plot_results(y=y_valid, yhat = yhat, n=250)
# Out:
# 0.843306597450281

# %%
t2 = var['Date'][1312:1544]

# %%
plt.plot(t2, yhat, label = "Prediction", color='red')

# plotting the line 2 points 
plt.plot(t2, y_valid, label = "Expectation", color='blue')
plt.xlabel('Date')
# Set the y axis label of the current axis.
plt.ylabel('Power Emission')
# Set a title of the current axes.
plt.title('NARX-SISO model simulation for Sustainable XNO-USD Currency')
# show a legend on the plot
plt.legend()
plt.savefig('SISO_fw.png')

# %%
len(yhat)
# Out:
# 232

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

rmse(yhat, S[1312:1544])

rmse(yhat, y_valid)
# Out:
# 0.024394047178000783

# %%
from sklearn.metrics import mean_squared_error

rms = mean_squared_error(S[1312:1544], yhat, squared=False)
rms
# Out:
# 0.024394047178000783

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_valid, yhat)
mae
# Out:
# 0.015690898414704738

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape=mean_absolute_percentage_error(y_valid, yhat)
mape
# Out:
# 1.7884566493166931

# %%
from numpy import savetxt
savetxt('yhat.csv', yhat, delimiter=',')
r.to_csv('Model_Structure.csv')
df_1 = pd.DataFrame(S[1312:1544], columns=['Expectation-O/P'])
df_1
# Out:
#      Expectation-O/P
# 0           0.001540
# 1          -0.032940
# 2          -0.032259
# 3           0.019253
# 4           0.034271
# ..               ...
# 227         0.037557
# 228         0.031142
# 229        -0.016223
# 230        -0.022966
# 231        -0.020821
#
# [232 rows x 1 columns]

# %%
df_1['Prediction-O/P'] = yhat
df_1
# Out:
#      Expectation-O/P  Prediction-O/P
# 0           0.001540        0.001540
# 1          -0.032940       -0.032940
# 2          -0.032259       -0.032259
# 3           0.019253        0.019253
# 4           0.034271        0.034271
# ..               ...             ...
# 227         0.037557        0.034906
# 228         0.031142        0.027027
# 229        -0.016223        0.008045
# 230        -0.022966       -0.008506
# 231        -0.020821       -0.010041
#
# [232 rows x 2 columns]

# %%
len(df_1)
df_1.columns
# Out:
# Index(['Expectation-O/P', 'Prediction-O/P'], dtype='object')

# %%
import plotly.express as px 
import pandas as pd 
import numpy as np 

# data
fig = px.line(df_1, x=var ['Date'][1312:1544], y= df_1.columns[0:2],labels=dict(value="Power Emission"),title="NARX-SISO model simulation for Sustainable XNO-USD Currency")

# Show plot 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

fig2 = go.Figure()
fig2.add_trace(go.Scatter(x= var['Date'][1312:1544], y=df_1["Expectation-O/P"], name="Expectation", mode="lines"))
fig2.add_trace(go.Scatter(x= var['Date'][1312:1544], y=df_1["Prediction-O/P"], name="Prediction", mode="lines"))
fig2.update_layout(
    title="NARX-SISO model simulation for Sustainable XNO-USD Currency", xaxis_title="Year", yaxis_title="Power Emission"
)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
