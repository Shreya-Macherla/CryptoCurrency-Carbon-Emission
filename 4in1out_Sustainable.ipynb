# %%
pip install sysidentpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 3.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f24bd886-67e4-4990-9e2a-4f6f2c09f30d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f24bd886-67e4-4990-9e2a-4f6f2c09f30d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install numpy pandas matplotlib statsmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from sysidentpy.model_structure_selection import FROLS
from sysidentpy.basis_function._basis_function import Polynomial
from sysidentpy.metrics import root_relative_squared_error
from sysidentpy.utils.display_results import results
from sysidentpy.utils.plotting import plot_residues_correlation, plot_results
from sysidentpy.residues.residues_correlation import compute_residues_autocorrelation, compute_cross_correlation
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
# %matplotlib inline
var=pd.read_excel('Final Dataset.xlsx', sheet_name='Model_Dataset', skiprows=[0, 2])
var.dropna(inplace=True)
var.head()
# Out:
#         Date   BNB-USD   BTC-USD   ETH-USD  USDT-USD   XRP-USD   ADA-USD  \
# 0 2019-01-03 -0.283723 -0.146478 -0.218059 -0.242175 -0.213296 -0.133797
# 1 2019-01-04  0.250258  0.067790  0.155431  0.110796  0.026443 -0.276461
# 2 2019-01-05  0.034520  0.058029  0.065619  0.024849  0.003227  0.448817
# 3 2019-01-06  0.314991  0.085648 -0.032553  0.056192  0.085732  0.716078
# 4 2019-01-07 -0.092145 -0.068087 -0.175156 -0.115993  0.013049 -0.117139
#
#    BITG-USD  MIOTA-USD   XNO-USD  POWR-USD     Power  Ground Transport  \
# 0  0.272976  -0.350994 -0.212519 -0.541858  0.017161          0.100704
# 1 -0.199125   0.001564  0.155184 -0.798119  0.015954          0.002050
# 2 -1.063302  -0.364719  0.394051  0.533827 -0.031367         -0.072048
# 3 -0.655398   0.427898  0.268170  1.404755 -0.020110         -0.145075
# 4  0.675955  -0.436056 -0.465483 -1.400369  0.045889          0.199612
#
#    Residential  Domestic Aviation  International Aviation
# ...

# %%
ADA_BITG_MIOTA_XNO_USD_var=var.iloc[:, 6:10]

# %%
ADA_BITG_MIOTA_XNO_USD_var
# Out:
#        ADA-USD  BITG-USD  MIOTA-USD   XNO-USD
# 0    -0.133797  0.272976  -0.350994 -0.212519
# 1    -0.276461 -0.199125   0.001564  0.155184
# 2     0.448817 -1.063302  -0.364719  0.394051
# 3     0.716078 -0.655398   0.427898  0.268170
# 4    -0.117139  0.675955  -0.436056 -0.465483
# ...        ...       ...        ...       ...
# 1544  0.317827 -0.029414   0.272392  0.560871
# 1545  0.055900  0.014815  -0.232628 -0.269928
# 1546  0.390388  1.317827   0.260564 -0.389168
# 1547 -0.188504 -0.472632  -0.222510 -0.139464
# 1548  0.488918  0.016702   0.036075 -0.113315
#
# [1510 rows x 4 columns]

# %%
output_var=var.iloc[:, 11]

# %%
var.isna()
# Out:
#        Date  BNB-USD  BTC-USD  ETH-USD  USDT-USD  XRP-USD  ADA-USD  BITG-USD  \
# 0     False    False    False    False     False    False    False     False
# 1     False    False    False    False     False    False    False     False
# 2     False    False    False    False     False    False    False     False
# 3     False    False    False    False     False    False    False     False
# 4     False    False    False    False     False    False    False     False
# ...     ...      ...      ...      ...       ...      ...      ...       ...
# 1544  False    False    False    False     False    False    False     False
# 1545  False    False    False    False     False    False    False     False
# 1546  False    False    False    False     False    False    False     False
# 1547  False    False    False    False     False    False    False     False
# 1548  False    False    False    False     False    False    False     False
#
# ...

# %%
var=var.drop(columns=["XRP-USD", "BNB-USD",	"BTC-USD",	"ETH-USD",	"USDT-USD",	"POWR-USD", "Ground Transport", "Residential", "Domestic Aviation", "International Aviation"])

# %%
var.isnull().sum()
# Out:
# Date         0
# ADA-USD      0
# BITG-USD     0
# MIOTA-USD    0
# XNO-USD      0
# Power        0
# dtype: int64

# %%
var.tail()
# Out:
#            Date   ADA-USD  BITG-USD  MIOTA-USD   XNO-USD     Power
# 1544 2023-03-27  0.317827 -0.029414   0.272392  0.560871  0.037557
# 1545 2023-03-28  0.055900  0.014815  -0.232628 -0.269928  0.031142
# 1546 2023-03-29  0.390388  1.317827   0.260564 -0.389168 -0.016223
# 1547 2023-03-30 -0.188504 -0.472632  -0.222510 -0.139464 -0.022966
# 1548 2023-03-31  0.488918  0.016702   0.036075 -0.113315 -0.020821

# %%
var['ADA-USD'][0:1550].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
var['BITG-USD'][0:1550].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
var['MIOTA-USD'][0:1550].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
var['XNO-USD'][0:1550].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
var[['ADA-USD', 'BITG-USD', 'MIOTA-USD', 'XNO-USD']][0:1550].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
var['Power'][0:1550].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
var[['ADA-USD', 'BITG-USD', 'MIOTA-USD', 'XNO-USD', 'Power']][0:1550].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
df=pd.DataFrame(var[['ADA-USD', 'BITG-USD', 'MIOTA-USD', 'XNO-USD']])
x = df.to_numpy()
df1=pd.DataFrame(var['Power'])
S= df1.to_numpy()

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x,S,train_size=0.85,shuffle= False)

# %%
df
# Out:
#        ADA-USD  BITG-USD  MIOTA-USD   XNO-USD
# 0    -0.133797  0.272976  -0.350994 -0.212519
# 1    -0.276461 -0.199125   0.001564  0.155184
# 2     0.448817 -1.063302  -0.364719  0.394051
# 3     0.716078 -0.655398   0.427898  0.268170
# 4    -0.117139  0.675955  -0.436056 -0.465483
# ...        ...       ...        ...       ...
# 1544  0.317827 -0.029414   0.272392  0.560871
# 1545  0.055900  0.014815  -0.232628 -0.269928
# 1546  0.390388  1.317827   0.260564 -0.389168
# 1547 -0.188504 -0.472632  -0.222510 -0.139464
# 1548  0.488918  0.016702   0.036075 -0.113315
#
# [1510 rows x 4 columns]

# %%
df1
# Out:
#          Power
# 0     0.017161
# 1     0.015954
# 2    -0.031367
# 3    -0.020110
# 4     0.045889
# ...        ...
# 1544  0.037557
# 1545  0.031142
# 1546 -0.016223
# 1547 -0.022966
# 1548 -0.020821
#
# [1510 rows x 1 columns]

# %%
len(x_valid)
# Out:
# 227

# %%
len(y_valid)
# len(y_train)
# Out:
# 227

# %%
len(x_train)
# Out:
# 1283

# %%
len(y_train)
# Out:
# 1283

# %%
# # Concatenate input features and target variable for the validation set
# valid_data = np.column_stack((x_valid, y_valid))

# %%
basis_function = Polynomial(degree=3)

model = FROLS(
    order_selection=True,
    n_terms=50,
    extended_least_squares=False,
    ylag=15,
    xlag=[15, 15, 15, 15],
    info_criteria='bic',
    estimator='least_squares',
    basis_function=basis_function
)
# Out:
# /usr/local/lib/python3.10/dist-packages/sysidentpy/utils/deprecation.py:37: FutureWarning: Passing a string to define the estimator will rise an error in v0.4.0.
#  You'll have to use FROLS(estimator=LeastSquares()) instead.
#  The only change is that you'll have to define the estimator first instead of passing a string like 'least_squares'.
#  This change will make easier to implement new estimators and it'll improve code readability.
#   warnings.warn(message, FutureWarning)

# %%
model.fit(X=x_train, y=y_train)

# %%
yhat = model.predict(X=x_valid, y=y_valid, steps_ahead=1)
rrse = root_relative_squared_error(y_valid, yhat)
print(rrse)

r = pd.DataFrame(
    results(
        model.final_model, model.theta, model.err,
        model.n_terms, err_precision=8, dtype='sci'
        ),
    columns=['Regressors', 'Parameters', 'ERR'])
print(r)
# Out:
# 0.735192633521765
#          Regressors   Parameters             ERR
# 0            y(k-7)   5.5641E-01  6.53715182E-01
# 1           y(k-14)   2.6788E-01  4.35445089E-02
# 2    x4(k-8)y(k-10)  -1.1940E+02  9.80795295E-03
# 3   x2(k-11)x1(k-1)  -3.4690E+01  6.67967351E-03
# 4     x3(k-4)y(k-3)   6.1491E+01  5.45133385E-03
# 5            y(k-2)  -2.9754E-01  9.02881632E-03
# 6            y(k-4)  -1.5170E-01  7.37555714E-03
# 7   x2(k-11)y(k-12)  -1.6633E+01  5.16542073E-03
# 8           x3(k-1)   5.0273E+00  6.54728445E-03
# 9    x1(k-10)y(k-2)  -1.2490E+00  6.63796531E-03
# 10         x1(k-11)  -1.6687E+00  5.06765270E-03
# 11  x4(k-12)y(k-15)  -8.0472E+01  5.69039661E-03
# 12    y(k-10)y(k-8)  -5.0713E+01  2.42575944E-03
# 13   x4(k-8)x1(k-5)  -4.0757E+01  2.30121467E-03
# 14   x3(k-14)y(k-7)   6.1361E-01  2.15287553E-03
# 15    x3(k-4)y(k-6)   9.5196E+01  1.90156075E-03
# 16  x4(k-14)y(k-14)   6.3564E+01  1.89619780E-03
# 17   x1(k-7)y(k-11)   6.6331E+00  1.59647224E-03
# ...

# %%
r["ERR"] = pd.to_numeric(r["ERR"], downcast="float")

print('Sum of ERR=  ',r['ERR'].sum())
# Out:
# Sum of ERR=   0.81629676

# %%
plot_results(y=y_valid, yhat = yhat, n=1000)
# ee = compute_residues_autocorrelation(y_valid, yhat)
# plot_residues_correlation(data=ee, title="Residues", ylabel="$e^2$")
# x1e = compute_cross_correlation(y_valid, yhat, x_valid)
# plot_residues_correlation(data=x1e, title="Residues", ylabel="$x_1e$")

# %%
t2 = var['Date'][1283:1520]

# %%
plt.plot(t2, yhat, label = "Prediction", color='red')

# plotting the line 2 points
plt.plot(t2, y_valid, label = "Expectation", color='blue')
plt.xlabel('Date')
# Set the y axis label of the current axis.
plt.ylabel('Power Emission')
# Set a title of the current axes.
plt.title('NARX-MISO model simulation for Sustainable ADA-BITG-MIOTA-XNO-USD Currency')
# show a legend on the plot
plt.legend()
plt.savefig('MISO_fw.png')

# %%
len(yhat)
# Out:
# 227

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

rmse(yhat, S[1283:1520])

rmse(yhat, y_valid)
# Out:
# 0.01946535025714324

# %%
from sklearn.metrics import mean_squared_error

rms = mean_squared_error(S[1283:1520], yhat, squared=False)
rms
# Out:
# 0.01946535025714324

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_valid, yhat)
mae
# Out:
# 0.013080204362975528

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape=mean_absolute_percentage_error(y_valid, yhat)
mape
# Out:
# 1.613885661415003

# %%
from numpy import savetxt
savetxt('yhat.csv', yhat, delimiter=',')
r.to_csv('Model_Structure.csv')
df_1 = pd.DataFrame(S[1283:1520], columns=['Expectation-O/P'])
df_1
# Out:
#      Expectation-O/P
# 0           0.006073
# 1          -0.006707
# 2          -0.010456
# 3          -0.028897
# 4          -0.027849
# ..               ...
# 222         0.037557
# 223         0.031142
# 224        -0.016223
# 225        -0.022966
# 226        -0.020821
#
# [227 rows x 1 columns]

# %%
df_1['Prediction-O/P'] = yhat
df_1
# Out:
#      Expectation-O/P  Prediction-O/P
# 0           0.006073        0.006073
# 1          -0.006707       -0.006707
# 2          -0.010456       -0.010456
# 3          -0.028897       -0.028897
# 4          -0.027849       -0.027849
# ..               ...             ...
# 222         0.037557        0.024018
# 223         0.031142        0.023732
# 224        -0.016223       -0.001342
# 225        -0.022966       -0.010371
# 226        -0.020821       -0.005071
#
# [227 rows x 2 columns]

# %%
len(df_1)
df_1.columns
# Out:
# Index(['Expectation-O/P', 'Prediction-O/P'], dtype='object')

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# data
fig = px.line(df_1, x=var ['Date'][1283:1520], y= df_1.columns[0:2],labels=dict(value="Power Emission"),title="NARX-MISO model simulation for ADA-BITG-MIOTA-XNO-USD Sustainable Currency")

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

fig2 = go.Figure()
fig2.add_trace(go.Scatter(x= var['Date'][1283:1520], y=df_1["Expectation-O/P"], name="Expectation", mode="lines"))
fig2.add_trace(go.Scatter(x= var['Date'][1283:1520], y=df_1["Prediction-O/P"], name="Prediction", mode="lines"))
fig2.update_layout(
    title="NARX-MISO model simulation for ADA-BITG-MIOTA-XNO-USD Sustainable Currency", xaxis_title="Year", yaxis_title="Power Emission"
)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
